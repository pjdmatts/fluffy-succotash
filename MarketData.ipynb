# %%
using Pkg
Pkg.add("MarketData")
# Out:
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#   No Changes to `~/.julia/environments/v1.7/Project.toml`
#   No Changes to `~/.julia/environments/v1.7/Manifest.toml`

# %%
using MarketData
APPL = yahoo(:AAPL)
# Out:
# 10390×6 TimeArray{Float64, 2, Date, Matrix{Float64}} 1980-12-12 to 2022-02-25
# │            │ Open   │ High   │ Low    │ Close  │ AdjClose │ Volume     │
# ├────────────┼────────┼────────┼────────┼────────┼──────────┼────────────┤
# │ 1980-12-12 │ 0.1283 │ 0.1289 │ 0.1283 │ 0.1283 │ 0.1003   │ 4.690336e8 │
# │ 1980-12-15 │ 0.1222 │ 0.1222 │ 0.1217 │ 0.1217 │ 0.0951   │ 1.758848e8 │
# │ 1980-12-16 │ 0.1133 │ 0.1133 │ 0.1127 │ 0.1127 │ 0.0881   │ 1.05728e8  │
# │ 1980-12-17 │ 0.1155 │ 0.1161 │ 0.1155 │ 0.1155 │ 0.0903   │ 8.64416e7  │
# │ 1980-12-18 │ 0.1189 │ 0.1194 │ 0.1189 │ 0.1189 │ 0.0929   │ 7.34496e7  │
# │ 1980-12-19 │ 0.1261 │ 0.1267 │ 0.1261 │ 0.1261 │ 0.0986   │ 4.86304e7  │
# │ 1980-12-22 │ 0.1323 │ 0.1328 │ 0.1323 │ 0.1323 │ 0.1034   │ 3.73632e7  │
# │ 1980-12-23 │ 0.1378 │ 0.1384 │ 0.1378 │ 0.1378 │ 0.1077   │ 4.69504e7  │
# │ 1980-12-24 │ 0.1451 │ 0.1456 │ 0.1451 │ 0.1451 │ 0.1134   │ 4.80032e7  │
# ...

# %%
using Plots

# %%
plot(AAPL[:Open])

# %% [markdown]
# https://docs.juliahub.com/MarketData/vKuMd/0.13.1/

# %% [markdown]
# https://juliastats.org/TimeSeries.jl/latest/

# %%
start = DateTime(2018, 1, 1)
# Out:
# 2018-01-01T00:00:00

# %%
APPL = yahoo(:AAPL, YahooOpt(period1 = start))
# Out:
# 1046×6 TimeArray{Float64, 2, Date, Matrix{Float64}} 2018-01-02 to 2022-02-25
# │            │ Open    │ High    │ Low     │ Close   │ AdjClose │ Volume     │
# ├────────────┼─────────┼─────────┼─────────┼─────────┼──────────┼────────────┤
# │ 2018-01-02 │ 42.54   │ 43.075  │ 42.315  │ 43.065  │ 41.1358  │ 1.022236e8 │
# │ 2018-01-03 │ 43.1325 │ 43.6375 │ 42.99   │ 43.0575 │ 41.1286  │ 1.180716e8 │
# │ 2018-01-04 │ 43.135  │ 43.3675 │ 43.02   │ 43.2575 │ 41.3196  │ 8.97384e7  │
# │ 2018-01-05 │ 43.36   │ 43.8425 │ 43.2625 │ 43.75   │ 41.7901  │ 9.464e7    │
# │ 2018-01-08 │ 43.5875 │ 43.9025 │ 43.4825 │ 43.5875 │ 41.6348  │ 8.22712e7  │
# │ 2018-01-09 │ 43.6375 │ 43.765  │ 43.3525 │ 43.5825 │ 41.6301  │ 8.6336e7   │
# │ 2018-01-10 │ 43.29   │ 43.575  │ 43.25   │ 43.5725 │ 41.6205  │ 9.58396e7  │
# │ 2018-01-11 │ 43.6475 │ 43.8725 │ 43.6225 │ 43.82   │ 41.8569  │ 7.46708e7  │
# │ 2018-01-12 │ 44.045  │ 44.34   │ 43.9125 │ 44.2725 │ 42.2892  │ 1.016724e8 │
# ...

# %%
plot(APPL[:Open])

# %%
t = Dates.now()
# Out:
# 2022-02-27T09:40:43.586

# %%
YahooOpt(period1 = t - Year(2), period2 = t)
# Out:
# YahooOpt with 4 entries:
#   :period1  => 1582796444
#   :period2  => 1645954844
#   :interval => "1d"
#   :events   => :history

# %%
testOpt = YahooOpt(period1 = t - Year(2), period2 = t)
# Out:
# YahooOpt with 4 entries:
#   :period1  => 1582796444
#   :period2  => 1645954844
#   :interval => "1d"
#   :events   => :history

# %%
APPL = yahoo(:AAPL, testOpt)
# Out:
# 505×6 TimeArray{Float64, 2, Date, Matrix{Float64}} 2020-02-27 to 2022-02-25
# │            │ Open    │ High    │ Low     │ Close   │ AdjClose │ Volume     │
# ├────────────┼─────────┼─────────┼─────────┼─────────┼──────────┼────────────┤
# │ 2020-02-27 │ 70.275  │ 71.5    │ 68.24   │ 68.38   │ 67.4531  │ 3.206056e8 │
# │ 2020-02-28 │ 64.315  │ 69.6025 │ 64.0925 │ 68.34   │ 67.4137  │ 4.2651e8   │
# │ 2020-03-02 │ 70.57   │ 75.36   │ 69.43   │ 74.7025 │ 73.6899  │ 3.413972e8 │
# │ 2020-03-03 │ 75.9175 │ 76.0    │ 71.45   │ 72.33   │ 71.3496  │ 3.194756e8 │
# │ 2020-03-04 │ 74.11   │ 75.85   │ 73.2825 │ 75.685  │ 74.6591  │ 2.191784e8 │
# │ 2020-03-05 │ 73.88   │ 74.8875 │ 72.8525 │ 73.23   │ 72.2374  │ 1.875728e8 │
# │ 2020-03-06 │ 70.5    │ 72.705  │ 70.3075 │ 72.2575 │ 71.2781  │ 2.261768e8 │
# │ 2020-03-09 │ 65.9375 │ 69.5225 │ 65.75   │ 66.5425 │ 65.6405  │ 2.867448e8 │
# │ 2020-03-10 │ 69.285  │ 71.61   │ 67.3425 │ 71.335  │ 70.3681  │ 2.8529e8   │
# ...

# %%
plot(APPL[:Open])

# %%
KN = yahoo(:KN, testOpt)
# Out:
# 505×6 TimeArray{Float64, 2, Date, Matrix{Float64}} 2020-02-27 to 2022-02-25
# │            │ Open  │ High  │ Low   │ Close │ AdjClose │ Volume   │
# ├────────────┼───────┼───────┼───────┼───────┼──────────┼──────────┤
# │ 2020-02-27 │ 16.72 │ 16.91 │ 16.33 │ 16.33 │ 16.33    │ 706600.0 │
# │ 2020-02-28 │ 15.95 │ 16.66 │ 15.85 │ 16.62 │ 16.62    │ 1.2926e6 │
# │ 2020-03-02 │ 16.72 │ 16.88 │ 16.29 │ 16.72 │ 16.72    │ 1.043e6  │
# │ 2020-03-03 │ 16.74 │ 17.13 │ 16.39 │ 16.58 │ 16.58    │ 1.6324e6 │
# │ 2020-03-04 │ 16.78 │ 16.94 │ 16.34 │ 16.87 │ 16.87    │ 799300.0 │
# │ 2020-03-05 │ 16.54 │ 16.69 │ 16.06 │ 16.3  │ 16.3     │ 903200.0 │
# │ 2020-03-06 │ 15.88 │ 16.25 │ 15.75 │ 16.25 │ 16.25    │ 675200.0 │
# │ 2020-03-09 │ 15.53 │ 15.93 │ 15.25 │ 15.33 │ 15.33    │ 1.41e6   │
# │ 2020-03-10 │ 15.63 │ 15.82 │ 14.83 │ 15.37 │ 15.37    │ 1.1114e6 │
# │ 2020-03-11 │ 15.0  │ 15.2  │ 14.66 │ 14.91 │ 14.91    │ 954000.0 │
# ...

# %%
plot(KN[:Open, :Close])

# %%
start = DateTime(2018, 1, 1)
# Out:
# 2018-01-01T00:00:00

# %%
KN = yahoo(:KN, YahooOpt(period1 = start))
# Out:
# 1046×6 TimeArray{Float64, 2, Date, Matrix{Float64}} 2018-01-02 to 2022-02-25
# │            │ Open  │ High  │ Low   │ Close │ AdjClose │ Volume   │
# ├────────────┼───────┼───────┼───────┼───────┼──────────┼──────────┤
# │ 2018-01-02 │ 14.78 │ 15.14 │ 14.67 │ 15.09 │ 15.09    │ 895600.0 │
# │ 2018-01-03 │ 15.11 │ 15.42 │ 15.11 │ 15.38 │ 15.38    │ 982500.0 │
# │ 2018-01-04 │ 15.42 │ 15.57 │ 15.23 │ 15.32 │ 15.32    │ 839800.0 │
# │ 2018-01-05 │ 15.42 │ 15.71 │ 15.42 │ 15.68 │ 15.68    │ 650300.0 │
# │ 2018-01-08 │ 15.64 │ 16.02 │ 15.57 │ 15.96 │ 15.96    │ 567000.0 │
# │ 2018-01-09 │ 15.95 │ 16.0  │ 15.69 │ 15.74 │ 15.74    │ 545100.0 │
# │ 2018-01-10 │ 15.63 │ 15.74 │ 15.58 │ 15.6  │ 15.6     │ 306000.0 │
# │ 2018-01-11 │ 15.59 │ 15.88 │ 15.55 │ 15.83 │ 15.83    │ 659900.0 │
# │ 2018-01-12 │ 15.86 │ 16.27 │ 15.81 │ 16.17 │ 16.17    │ 897900.0 │
# │ 2018-01-16 │ 16.33 │ 16.62 │ 16.12 │ 16.29 │ 16.29    │ 942100.0 │
# ...

# %%
plot(KN[:Open])

# %%
plot(KN[:Open, :Close])

# %%
plot(KN[:High, :Low])

# %%
KN[end]
# Out:
# 1×6 TimeArray{Float64, 2, Date, Matrix{Float64}} 2022-02-25 to 2022-02-25
# │            │ Open  │ High  │ Low   │ Close │ AdjClose │ Volume   │
# ├────────────┼───────┼───────┼───────┼───────┼──────────┼──────────┤
# │ 2022-02-25 │ 21.69 │ 21.91 │ 21.64 │ 21.82 │ 21.82    │ 883400.0 │

# %%
KN[1]
# Out:
# 1×6 TimeArray{Float64, 2, Date, Matrix{Float64}} 2018-01-02 to 2018-01-02
# │            │ Open  │ High  │ Low   │ Close │ AdjClose │ Volume   │
# ├────────────┼───────┼───────┼───────┼───────┼──────────┼──────────┤
# │ 2018-01-02 │ 14.78 │ 15.14 │ 14.67 │ 15.09 │ 15.09    │ 895600.0 │

# %%
KN[[Date(2020, 1, 3)]]
# Out:
# 1×6 TimeArray{Float64, 2, Date, Matrix{Float64}} 2020-01-03 to 2020-01-03
# │            │ Open  │ High  │ Low   │ Close │ AdjClose │ Volume   │
# ├────────────┼───────┼───────┼───────┼───────┼──────────┼──────────┤
# │ 2020-01-03 │ 21.11 │ 21.46 │ 21.02 │ 21.39 │ 21.39    │ 686700.0 │

# %%
plot(KN[:Volume])

# %%
start = DateTime(2022, 1, 1)
# Out:
# 2022-01-01T00:00:00

# %%
KN = yahoo(:KN, YahooOpt(period1 = start))
# Out:
# 38×6 TimeArray{Float64, 2, Date, Matrix{Float64}} 2022-01-03 to 2022-02-25
# │            │ Open  │ High  │ Low   │ Close │ AdjClose │ Volume   │
# ├────────────┼───────┼───────┼───────┼───────┼──────────┼──────────┤
# │ 2022-01-03 │ 23.45 │ 23.65 │ 23.29 │ 23.37 │ 23.37    │ 1.2575e6 │
# │ 2022-01-04 │ 23.41 │ 23.71 │ 23.35 │ 23.59 │ 23.59    │ 1.0297e6 │
# │ 2022-01-05 │ 23.56 │ 23.81 │ 23.48 │ 23.54 │ 23.54    │ 929500.0 │
# │ 2022-01-06 │ 23.43 │ 23.63 │ 23.36 │ 23.5  │ 23.5     │ 1.0523e6 │
# │ 2022-01-07 │ 23.43 │ 23.52 │ 23.22 │ 23.28 │ 23.28    │ 595300.0 │
# │ 2022-01-10 │ 23.16 │ 23.23 │ 22.9  │ 23.21 │ 23.21    │ 1.2169e6 │
# │ 2022-01-11 │ 23.24 │ 23.32 │ 22.99 │ 23.14 │ 23.14    │ 684100.0 │
# │ 2022-01-12 │ 23.25 │ 23.35 │ 23.04 │ 23.16 │ 23.16    │ 546400.0 │
# │ 2022-01-13 │ 23.23 │ 23.37 │ 22.99 │ 23.05 │ 23.05    │ 529000.0 │
# │ 2022-01-14 │ 22.93 │ 23.24 │ 22.88 │ 23.15 │ 23.15    │ 494500.0 │
# │ 2022-01-18 │ 22.97 │ 22.97 │ 22.75 │ 22.84 │ 22.84    │ 905600.0 │
# ...

# %%
plot(KN[:Close])

# %%
start = DateTime(2021, 1, 1)
# Out:
# 2021-01-01T00:00:00

# %%
KN = yahoo(:KN, YahooOpt(period1 = start))
# Out:
# 290×6 TimeArray{Float64, 2, Date, Matrix{Float64}} 2021-01-04 to 2022-02-25
# │            │ Open  │ High  │ Low   │ Close │ AdjClose │ Volume   │
# ├────────────┼───────┼───────┼───────┼───────┼──────────┼──────────┤
# │ 2021-01-04 │ 18.59 │ 18.67 │ 17.89 │ 18.12 │ 18.12    │ 767900.0 │
# │ 2021-01-05 │ 18.15 │ 18.63 │ 18.15 │ 18.39 │ 18.39    │ 662100.0 │
# │ 2021-01-06 │ 18.72 │ 19.27 │ 18.7  │ 19.05 │ 19.05    │ 1.135e6  │
# │ 2021-01-07 │ 19.06 │ 19.31 │ 19.03 │ 19.27 │ 19.27    │ 498400.0 │
# │ 2021-01-08 │ 19.3  │ 19.3  │ 18.78 │ 18.98 │ 18.98    │ 559800.0 │
# │ 2021-01-11 │ 18.73 │ 19.44 │ 18.6  │ 19.25 │ 19.25    │ 828900.0 │
# │ 2021-01-12 │ 19.46 │ 19.59 │ 19.26 │ 19.29 │ 19.29    │ 763600.0 │
# │ 2021-01-13 │ 19.33 │ 19.5  │ 18.85 │ 18.97 │ 18.97    │ 463400.0 │
# │ 2021-01-14 │ 19.12 │ 19.22 │ 18.73 │ 18.74 │ 18.74    │ 524000.0 │
# │ 2021-01-15 │ 18.55 │ 18.57 │ 18.32 │ 18.45 │ 18.45    │ 616700.0 │
# ...

# %%
plot(KN[:Close])

# %%
what = KN[:Close]
# Out:
# 290×1 TimeArray{Float64, 1, Date, Vector{Float64}} 2021-01-04 to 2022-02-25
# │            │ Close │
# ├────────────┼───────┤
# │ 2021-01-04 │ 18.12 │
# │ 2021-01-05 │ 18.39 │
# │ 2021-01-06 │ 19.05 │
# │ 2021-01-07 │ 19.27 │
# │ 2021-01-08 │ 18.98 │
# │ 2021-01-11 │ 19.25 │
# │ 2021-01-12 │ 19.29 │
# │ 2021-01-13 │ 18.97 │
# │ 2021-01-14 │ 18.74 │
# │ 2021-01-15 │ 18.45 │
# │ 2021-01-19 │ 19.26 │
# │ ⋮          │ ⋮     │
# │ 2022-02-11 │ 21.75 │
# │ 2022-02-14 │ 21.62 │
# │ 2022-02-15 │ 21.82 │
# │ 2022-02-16 │ 22.05 │
# │ 2022-02-17 │ 21.86 │
# │ 2022-02-18 │ 21.8  │
# │ 2022-02-22 │ 21.68 │
# │ 2022-02-23 │ 21.53 │
# │ 2022-02-24 │ 21.67 │
# │ 2022-02-25 │ 21.82 │

# %%
what[1]
# Out:
# 1×1 TimeArray{Float64, 1, Date, Vector{Float64}} 2021-01-04 to 2021-01-04
# │            │ Close │
# ├────────────┼───────┤
# │ 2021-01-04 │ 18.12 │

# %%
what[2]
# Out:
# 1×1 TimeArray{Float64, 1, Date, Vector{Float64}} 2021-01-05 to 2021-01-05
# │            │ Close │
# ├────────────┼───────┤
# │ 2021-01-05 │ 18.39 │

# %%
KN[end]
# Out:
# 1×6 TimeArray{Float64, 2, Date, Matrix{Float64}} 2022-02-25 to 2022-02-25
# │            │ Open  │ High  │ Low   │ Close │ AdjClose │ Volume   │
# ├────────────┼───────┼───────┼───────┼───────┼──────────┼──────────┤
# │ 2022-02-25 │ 21.69 │ 21.91 │ 21.64 │ 21.82 │ 21.82    │ 883400.0 │

# %%
KN
# Out:
# 290×6 TimeArray{Float64, 2, Date, Matrix{Float64}} 2021-01-04 to 2022-02-25
# │            │ Open  │ High  │ Low   │ Close │ AdjClose │ Volume   │
# ├────────────┼───────┼───────┼───────┼───────┼──────────┼──────────┤
# │ 2021-01-04 │ 18.59 │ 18.67 │ 17.89 │ 18.12 │ 18.12    │ 767900.0 │
# │ 2021-01-05 │ 18.15 │ 18.63 │ 18.15 │ 18.39 │ 18.39    │ 662100.0 │
# │ 2021-01-06 │ 18.72 │ 19.27 │ 18.7  │ 19.05 │ 19.05    │ 1.135e6  │
# │ 2021-01-07 │ 19.06 │ 19.31 │ 19.03 │ 19.27 │ 19.27    │ 498400.0 │
# │ 2021-01-08 │ 19.3  │ 19.3  │ 18.78 │ 18.98 │ 18.98    │ 559800.0 │
# │ 2021-01-11 │ 18.73 │ 19.44 │ 18.6  │ 19.25 │ 19.25    │ 828900.0 │
# │ 2021-01-12 │ 19.46 │ 19.59 │ 19.26 │ 19.29 │ 19.29    │ 763600.0 │
# │ 2021-01-13 │ 19.33 │ 19.5  │ 18.85 │ 18.97 │ 18.97    │ 463400.0 │
# │ 2021-01-14 │ 19.12 │ 19.22 │ 18.73 │ 18.74 │ 18.74    │ 524000.0 │
# │ 2021-01-15 │ 18.55 │ 18.57 │ 18.32 │ 18.45 │ 18.45    │ 616700.0 │
# ...

# %%
KN[:Close]
# Out:
# 290×1 TimeArray{Float64, 1, Date, Vector{Float64}} 2021-01-04 to 2022-02-25
# │            │ Close │
# ├────────────┼───────┤
# │ 2021-01-04 │ 18.12 │
# │ 2021-01-05 │ 18.39 │
# │ 2021-01-06 │ 19.05 │
# │ 2021-01-07 │ 19.27 │
# │ 2021-01-08 │ 18.98 │
# │ 2021-01-11 │ 19.25 │
# │ 2021-01-12 │ 19.29 │
# │ 2021-01-13 │ 18.97 │
# │ 2021-01-14 │ 18.74 │
# │ 2021-01-15 │ 18.45 │
# │ 2021-01-19 │ 19.26 │
# │ ⋮          │ ⋮     │
# │ 2022-02-11 │ 21.75 │
# │ 2022-02-14 │ 21.62 │
# │ 2022-02-15 │ 21.82 │
# │ 2022-02-16 │ 22.05 │
# │ 2022-02-17 │ 21.86 │
# │ 2022-02-18 │ 21.8  │
# │ 2022-02-22 │ 21.68 │
# │ 2022-02-23 │ 21.53 │
# │ 2022-02-24 │ 21.67 │
# │ 2022-02-25 │ 21.82 │

# %%
colnames(KN)
# Out:
# 6-element Vector{Symbol}:
#  :Open
#  :High
#  :Low
#  :Close
#  :AdjClose
#  :Volume

# %%
values(KN)
# Out:
# 290×6 Matrix{Float64}:
#  18.59  18.67  17.89  18.12  18.12  767900.0
#  18.15  18.63  18.15  18.39  18.39  662100.0
#  18.72  19.27  18.7   19.05  19.05       1.135e6
#  19.06  19.31  19.03  19.27  19.27  498400.0
#  19.3   19.3   18.78  18.98  18.98  559800.0
#  18.73  19.44  18.6   19.25  19.25  828900.0
#  19.46  19.59  19.26  19.29  19.29  763600.0
#  19.33  19.5   18.85  18.97  18.97  463400.0
#  19.12  19.22  18.73  18.74  18.74  524000.0
#  18.55  18.57  18.32  18.45  18.45  616700.0
#  18.71  19.3   18.6   19.26  19.26       1.1251e6
#  19.32  19.89  19.32  19.75  19.75  953400.0
#  19.9   19.99  19.71  19.88  19.88  669100.0
#   ⋮                                      ⋮
#  21.42  21.48  21.29  21.42  21.42  681500.0
#  23.23  23.41  22.1   22.21  22.21       2.0235e6
#  22.33  22.36  21.63  21.75  21.75       1.7392e6
#  21.72  21.87  21.53  21.62  21.62       1.2451e6
#  21.73  21.88  21.69  21.82  21.82  822600.0
#  21.76  22.16  21.68  22.05  22.05  703500.0
# ...

# %%
values(KN[:Close])
# Out:
# 290-element Vector{Float64}:
#  18.120001
#  18.389999
#  19.049999
#  19.27
#  18.98
#  19.25
#  19.290001
#  18.969999
#  18.74
#  18.450001
#  19.26
#  19.75
#  19.879999
#   ⋮
#  21.42
#  22.209999
#  21.75
#  21.620001
#  21.82
#  22.049999
#  21.860001
#  21.799999
#  21.68
#  21.530001
#  21.67
#  21.82

# %%
plot(values(KN[:Close]))

# %% [markdown]
# https://juliastats.org/TimeSeries.jl/latest/timearray/#Fields-getter-functions-1
